# %% [markdown]
# # Data Collection and Analysis Exam

# %% [markdown]
# Candidate number : 1012

# %%
from PIL import Image

# %% [markdown]
# ## Problem 1:
# #### What are escape sequences? Explain any 3 escape sequences.?
# Escape sequences is presented as ( \ ), thenceforth followed by some special characters that later shifts into strings.
#
#  3 examples:
# - Backspace -> \b
# - Backlash -> \
# - New line -> \n
#
#
#
# #### What are data types? What are Python’s built-in core data types.
#
# where data is categorized in items and represents divergent types of data. These values decides the operations that can be accomplished on spesific data.
#
#
# - Numbers(int, float, complex), boolean, set, dictionaries, sequences(String, List, Tuple)
#
# #### What do you mean by positive correlation and negative correlation? Give one example of each.
#
# the value from the correlation coefficient can result in a either negative or positive correlation.
#
# ##### Positive
# A positive correlation coefficient - > 0<𝑟⩽1
# displays two variables that are correlated positively. They work in paralell where if one of the variables increase, the other one will as well.
#
# - example :
# An example of positive correlation appears if u jog or run, either outside or on a threadmill. The more you run; calories burned will increase.
#
#
#
#
# ##### negative
# A negative correlation coefficient - > –1⩽𝑟<0
#
# Displays two variables that are correlated negatively. They work opposite of each other. This means that if one variable is increasing, the other one will in fact decrease.
#
# - example :
#
# An example of negative correlation may appear in the winter, when it gets darker in Norway. people will then be dependent on more light inside the houses.
#
#
# (https://www.embibe.com/exams/positive-and-negative-correlation/)
#
#
#
#
# #### What do you mean by five-point summary of data? Which plot is used to reflect five-point summary of data?
#
# five-point summary demonstrates a visual plot of the input data that presents an overview of spread, observation, distribution and location. From a five-point summary we will get the median value is displayed. We will then get a perspective view of the upper quartile values that equals to 75%, further the lower quartile that equals to 25%. In addition to this we'll get information about what the maximum and minimum values are.
#
#
# Box-plot is the chosen one to display a five-point summary:
# ![alt text](img.png)
#
# (https://tealfeed.com/five-point-summary-box-plot-explained-lh1l7)
#
#
# #### What is difference between univariate, bivariate and multivariate analysis? Give one example each of the plots used for these analysis.
# between these analyses we have a slight difference in number of variables that they are consisted of.
#
# 1. Univeriate data:
# This data only use one variable. It's informated to be the easiest analyse where one quantity is being dealt with. With the lack of analyses of relationships and causes, this type of data is only describing it, as well as discovering spesific patterns within it.
#
# - Can for example be analyzing the size of a houshold.
#
# 2. Bivariate data:
# This data uses two variables. compared to Univeriate data, the realtionships and causes are being dealt with here. Bivariate data gives us relationship between the two different variables.
#
# - Example can be firewood sales and temperature measutements in the winter.
#
# 3. Multivariate data:
# The word Multivariate says itself what this data type implies.
# This data uses three variables or more.
#
#
# - Example could be when a cinema wishes to analyze the comparison of popularity between three movies running. Giving the audience oppurunity to rate these movies and calculate the answers from women and men to then give us the relationship examiniation between these variables.
#
# (https://www.geeksforgeeks.org/univariate-bivariate-and-multivariate-data-and-its-analysis/)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Problem 2:
# #### 1. Write a python program to print the following pattern

# %%
for r in range(0,7):
    
    for c in range(0,7):
        
        if ( (c==0 or c==6) and r!=0) or ( (r==0 or r==6) and (c>-1 and c<8) ): 
            print("#", end='')
            
        else:
            print(end=' ')
    print()
# Out:
# #######
# #     #
# #     #
# #     #
# #     #
# #     #
# #######

# %% [markdown]
# #### 2. Write a Python program to input marks in 3 subjects; compute average and then calculate grade as per following guidelines

# %%
subject1 = int (input 
                ("please input ur first mark for the first subject: "))
subject2 = int (input 
                ("please input ur second mark for the second subject: "))
subject3 = int (input 
                ("please input ur third mark for the third subject: "))
average = (subject1 + subject2 + subject3) / 3
print ("Your average mark is : ",
       average)

guidelines = ((subject1 + subject2 + subject3)
       /300)*100

if guidelines >= 90 :
    print("Delimitation: Greater than or equal to 90")
    print ("Grade: A")
    
elif guidelines <= 89 and guidelines >= 80 :
    print("Delimitation: 89 to 80")
    print ("Grade: B")
    
elif guidelines <= 79 and guidelines >= 60 :
    print("Delimitation: 79 to 60")
    print ("Grade: C")
    
elif guidelines <= 59 and guidelines >= 50 :
    print("Delimitation: 59 to 50")
    print ("Grade: D")
    
elif guidelines <= 49 and guidelines >= 40 :
    print("Delimitation: 49 to 40")
    print ("Grade: E")
    
elif guidelines <= 39 :
    print("Delimitation: Less than or equal to 39")
    print ("Grade: F")
# Out:
# please input ur first mark for the first subject: 80
# please input ur second mark for the second subject: 70
# please input ur third mark for the third subject: 60
# Your average mark is :  70.0
# Delimitation: 79 to 60
# Grade: C

# %% [markdown]
# ## Problem 3: Data Wrangling and Plotting Problem
#
# ### For this exercise, we will use Automobile Dataset which has been provided to you in the file auto_data.csv. Perform the following tasks:
#
# #### 1. Read the csv file in Pandas and create a DataFrame named Auto_df. What is the shape of Auto_df. Print first 7 and last 7 rows of Auto_df.

# %%
dataset = "auto_data.csv"
fileOpener = open(dataset, "r")
print("name:", fileOpener.name)
print("mode: ", fileOpener.mode)
# Out:
# name: auto_data.csv
# mode:  r

# %%
fileOpener.close()

# %%
Auto_df = pd.read_csv('auto_data.csv', index_col = 0, sep = ",")             
Auto_df
# Out:
#           normalized-losses         make fuel-type aspiration num-of-doors  \
# symboling
#  3                        ?  alfa-romero       gas        std          two
#  3                        ?  alfa-romero       gas        std          two
#  1                        ?  alfa-romero       gas        std          two
#  2                      164         audi       gas        std         four
#  2                      164         audi       gas        std         four
# ...                     ...          ...       ...        ...          ...
# -1                       95        volvo       gas        std         four
# -1                       95        volvo       gas      turbo         four
# -1                       95        volvo       gas        std         four
# -1                       95        volvo    diesel      turbo         four
# -1                       95        volvo       gas      turbo         four
#
# ...

# %%
print(Auto_df)
# Out:
#           normalized-losses         make fuel-type aspiration num-of-doors  \
# symboling
#  3                        ?  alfa-romero       gas        std          two
#  3                        ?  alfa-romero       gas        std          two
#  1                        ?  alfa-romero       gas        std          two
#  2                      164         audi       gas        std         four
#  2                      164         audi       gas        std         four
# ...                     ...          ...       ...        ...          ...
# -1                       95        volvo       gas        std         four
# -1                       95        volvo       gas      turbo         four
# -1                       95        volvo       gas        std         four
# -1                       95        volvo    diesel      turbo         four
# -1                       95        volvo       gas      turbo         four
#
# ...

# %%
Auto_df.shape
# Out:
# (205, 25)

# %%
Auto_df.head(7)
# Out:
#           normalized-losses         make fuel-type aspiration num-of-doors  \
# symboling
# 3                         ?  alfa-romero       gas        std          two
# 3                         ?  alfa-romero       gas        std          two
# 1                         ?  alfa-romero       gas        std          two
# 2                       164         audi       gas        std         four
# 2                       164         audi       gas        std         four
# 2                         ?         audi       gas        std          two
# 1                       158         audi       gas        std         four
#
#             body-style drive-wheels engine-location  wheel-base  length  ...  \
# symboling                                                                ...
# 3          convertible          rwd           front        88.6   168.8  ...
# 3          convertible          rwd           front        88.6   168.8  ...
# ...

# %%
Auto_df.tail(7)
# Out:
#           normalized-losses   make fuel-type aspiration num-of-doors  \
# symboling
# -2                      103  volvo       gas      turbo         four
# -1                       74  volvo       gas      turbo         four
# -1                       95  volvo       gas        std         four
# -1                       95  volvo       gas      turbo         four
# -1                       95  volvo       gas        std         four
# -1                       95  volvo    diesel      turbo         four
# -1                       95  volvo       gas      turbo         four
#
#           body-style drive-wheels engine-location  wheel-base  length  ...  \
# symboling                                                              ...
# -2             sedan          rwd           front       104.3   188.8  ...
# -1             wagon          rwd           front       104.3   188.8  ...
# -1             sedan          rwd           front       109.1   188.8  ...
# ...

# %% [markdown]
# #### 2. Do you find anything unusual in the dataset? If yes, then replace these unusual values with NaN values.

# %%
#Spotted question marks in df
#I could check some columns for "?", 
#but why not just immediately convert the "?" to nan in the entire Datafram

Autoo_df = Auto_df.replace('?', np.NaN)
Autoo_df
# Out:
#           normalized-losses         make fuel-type aspiration num-of-doors  \
# symboling
#  3                      NaN  alfa-romero       gas        std          two
#  3                      NaN  alfa-romero       gas        std          two
#  1                      NaN  alfa-romero       gas        std          two
#  2                      164         audi       gas        std         four
#  2                      164         audi       gas        std         four
# ...                     ...          ...       ...        ...          ...
# -1                       95        volvo       gas        std         four
# -1                       95        volvo       gas      turbo         four
# -1                       95        volvo       gas        std         four
# -1                       95        volvo    diesel      turbo         four
# -1                       95        volvo       gas      turbo         four
#
# ...

# %% [markdown]
# #### 3. Which columns have NaN values and how many? Finally, handle these null values using any strategy taught in the class.

# %%
print("Checking which columns that have values with missing data: ")
print(Autoo_df.isnull().any())
# Out:
# Checking which columns that have values with missing data:
# normalized-losses     True
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors          True
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                  True
# stroke                True
# compression-ratio    False
# horsepower            True
# peak-rpm              True
# city-mpg             False
# highway-mpg          False
# price                 True
# dtype: bool

# %%
print("Checking the amount again, but now which of missing data: ")
Autoo_df.isnull().sum()
# Out:
# Checking the amount again, but now which of missing data:
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# ##### NaN values discovered:
#     - normalized-losses -> 41
#     - num-of-doors ->      2
#     - bore       ->        4
#     - stroke      ->       4
#     - peak-rpm     ->      2
#     - horsepower    ->     2
#     - price         ->     4

# %%
Autoo_df.value_counts().sum()
# Out:
# 159

# %%
Autoo_df = Autoo_df.fillna( method = 'bfill')

# %%
null = Autoo_df['normalized-losses']
null
# Out:
# symboling
#  3    164
#  3    164
#  1    164
#  2    164
#  2    164
#      ...
# -1     95
# -1     95
# -1     95
# -1     95
# -1     95
# Name: normalized-losses, Length: 205, dtype: object

# %%
null_mean = null.mean()
null_mean

# %% [markdown]
# hmm, we're not supposed to get inf. I'll solve this by this:

# %%
null_mean = null.mean()
null_mean
# Out:
# inf

# %%
remove_null = null.fillna(0)

# %%
null.fillna(null_mean, inplace=True)

# %%
Autoo_df.isnull().sum()
# Out:
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
Autoo_df.value_counts().sum()
# Out:
# 205

# %% [markdown]
# #### 4. Name the columns that have datatype as “object”.

# %%
Autoo_df.dtypes
# Out:
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
list(Autoo_df.select_dtypes(['object']).columns)
# Out:
# ['normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'engine-type',
#  'num-of-cylinders',
#  'fuel-system']

# %% [markdown]
# #### 5. What is the mean and median value for the length and width column?

# %%
mean = Autoo_df[['length', 'width']].mean()

print("Mean value for width and length:\n", mean)
# Out:
# Mean value for width and length:
#  length    174.049268
# width      65.907805
# dtype: float64

# %%
median = Autoo_df[['length', 'width']].median()
print("Median value for width and length:\n", median)
# Out:
# Median value for width and length:
#  length    173.2
# width      65.5
# dtype: float64

# %% [markdown]
# #### 6. The fuel consumption of the vehicles on the highway is given in miles per gallon (mpg) in the column “highway-mpg”. Transform the mpg to L/100km (using formula L/100km = 235/mpg) in the column of “highway-mpg” and change the name of column to “highway-L/100km”.

# %%
lKm = 235/Autoo_df['highway-mpg']
lKm
# Out:
# symboling
#  3     8.703704
#  3     8.703704
#  1     9.038462
#  2     7.833333
#  2    10.681818
#         ...
# -1     8.392857
# -1     9.400000
# -1    10.217391
# -1     8.703704
# -1     9.400000
# Name: highway-mpg, Length: 205, dtype: float64

# %%
Autoo_df['highway-mpg'] = lKm
Autoo_df
# Out:
#           normalized-losses         make fuel-type aspiration num-of-doors  \
# symboling
#  3                      164  alfa-romero       gas        std          two
#  3                      164  alfa-romero       gas        std          two
#  1                      164  alfa-romero       gas        std          two
#  2                      164         audi       gas        std         four
#  2                      164         audi       gas        std         four
# ...                     ...          ...       ...        ...          ...
# -1                       95        volvo       gas        std         four
# -1                       95        volvo       gas      turbo         four
# -1                       95        volvo       gas        std         four
# -1                       95        volvo    diesel      turbo         four
# -1                       95        volvo       gas      turbo         four
#
# ...

# %%
Autoo_df.rename(columns = {'highway-mpg': 'highway-L/100km'}, inplace = True)

# %%
Autoo_df
# Out:
#           normalized-losses         make fuel-type aspiration num-of-doors  \
# symboling
#  3                      164  alfa-romero       gas        std          two
#  3                      164  alfa-romero       gas        std          two
#  1                      164  alfa-romero       gas        std          two
#  2                      164         audi       gas        std         four
#  2                      164         audi       gas        std         four
# ...                     ...          ...       ...        ...          ...
# -1                       95        volvo       gas        std         four
# -1                       95        volvo       gas      turbo         four
# -1                       95        volvo       gas        std         four
# -1                       95        volvo    diesel      turbo         four
# -1                       95        volvo       gas      turbo         four
#
# ...

# %% [markdown]
# #### 7. Make a box plot for the curb-weight showing the 5-point summary.

# %%
import seaborn as sns

sns.set(style='white')

# %%
Autoo_df.describe()
# Out:
#        wheel-base      length       width      height  curb-weight  \
# count  205.000000  205.000000  205.000000  205.000000   205.000000
# mean    98.756585  174.049268   65.907805   53.724878  2555.565854
# std      6.021776   12.337289    2.145204    2.443522   520.680204
# min     86.600000  141.100000   60.300000   47.800000  1488.000000
# 25%     94.500000  166.300000   64.100000   52.000000  2145.000000
# 50%     97.000000  173.200000   65.500000   54.100000  2414.000000
# 75%    102.400000  183.100000   66.900000   55.500000  2935.000000
# max    120.900000  208.100000   72.300000   59.800000  4066.000000
#
#        engine-size        bore      stroke  compression-ratio  horsepower  \
# count   205.000000  205.000000  205.000000         205.000000  205.000000
# mean    126.907317    3.330927    3.258049          10.142537  104.312195
# std      41.642693    0.270973    0.314152           3.972040   39.523263
# ...

# %%
sns.boxplot(data = Autoo_df, y = 'curb-weight')
# Out:
# <AxesSubplot:ylabel='curb-weight'>

# %% [markdown]
# #### 8. For the column “horsepower”, discretize the data into 5 bins and draw a histogram.

# %%
import plotly.express as px

# %%
horsepower_df = Autoo_df[['horsepower']].copy()
print(horsepower_df)
# Out:
#            horsepower
# symboling
#  3              111.0
#  3              111.0
#  1              154.0
#  2              102.0
#  2              115.0
# ...               ...
# -1              114.0
# -1              160.0
# -1              134.0
# -1              106.0
# -1              114.0
#
# [205 rows x 1 columns]

# %%
sns.distplot(a = Autoo_df['horsepower'],
             rug = False, 
             hist = True, 
             bins = 5, 
             kde = False, 
             color = 'black')
# Out:
# /Users/yousra/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='horsepower'>

# %% [markdown]
# ####  9. Find the Spearman correlation between the following columns: bore, stroke, compression-ratio and horsepower

# %%
from scipy.stats import spearmanr

# %%
spearCorr_df = Autoo_df[['bore', 'stroke', 'compression-ratio', 'horsepower']].dropna()
spearCorr_df
# Out:
#            bore  stroke  compression-ratio  horsepower
# symboling
#  3         3.47    2.68                9.0       111.0
#  3         3.47    2.68                9.0       111.0
#  1         2.68    3.47                9.0       154.0
#  2         3.19    3.40               10.0       102.0
#  2         3.19    3.40                8.0       115.0
# ...         ...     ...                ...         ...
# -1         3.78    3.15                9.5       114.0
# -1         3.78    3.15                8.7       160.0
# -1         3.58    2.87                8.8       134.0
# -1         3.01    3.40               23.0       106.0
# -1         3.78    3.15                9.5       114.0
#
# [205 rows x 4 columns]

# %%
spearmanr(spearCorr_df)
# Out:
# SpearmanrResult(correlation=array([[ 1.        , -0.08256061, -0.15572   ,  0.64428948],
#        [-0.08256061,  1.        , -0.06313445,  0.1417982 ],
#        [-0.15572   , -0.06313445,  1.        , -0.35661407],
#        [ 0.64428948,  0.1417982 , -0.35661407,  1.        ]]), pvalue=array([[0.00000000e+00, 2.39247325e-01, 2.57769166e-02, 1.96676012e-25],
#        [2.39247325e-01, 0.00000000e+00, 3.68483351e-01, 4.25514669e-02],
#        [2.57769166e-02, 3.68483351e-01, 0.00000000e+00, 1.53511782e-07],
#        [1.96676012e-25, 4.25514669e-02, 1.53511782e-07, 0.00000000e+00]]))

# %% [markdown]
# #### 10. Given the correlation results between "price" and "stroke", do you expect a linear relationship? Verify your results using the function "regplot()"

# %%
price_stroke = Autoo_df[['price', 'stroke']].dropna()
price_stroke
# Out:
#              price  stroke
# symboling
#  3         13495.0    2.68
#  3         16500.0    2.68
#  1         16500.0    3.47
#  2         13950.0    3.40
#  2         17450.0    3.40
# ...            ...     ...
# -1         16845.0    3.15
# -1         19045.0    3.15
# -1         21485.0    2.87
# -1         22470.0    3.40
# -1         22625.0    3.15
#
# [205 rows x 2 columns]

# %%
price_stroke.corr(method = 'spearman')
# Out:
#            price    stroke
# price   1.000000  0.115514
# stroke  0.115514  1.000000

# %% [markdown]
# it seems like it will be a linear relationshit, it may seem very vertical, but has a slight tilt to it. The reason for me thinking that is because the distance to 1/-1 is short.

# %%
sns.set_style('dark')

# %%
sns.regplot(y = 'stroke', x = 'price', data = price_stroke)
plt.show()

# %% [markdown]
# #### 11. Make a box plot between “body-style” and “price”. Which body-style has the maximum outliers in price?

# %%
df = Autoo_df.explode('price')
df['price'] = df['price'].astype('float')
sns.boxplot(data=df, x='body-style', y='price')
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %% [markdown]
# sedan is the body-style with the maximum outlier in price.

# %% [markdown]
# #### 12. Into how many categories can vehicles be categorized based on drive-wheels? How many vehicles are four-wheel drive (i.e. 4wd)?

# %%
value = Autoo_df.groupby("drive-wheels").size()
value
# Out:
# drive-wheels
# 4wd      9
# fwd    120
# rwd     76
# dtype: int64

# %% [markdown]
# There is in total 3 categories.

# %%
p = dict(list(Autoo_df.groupby('drive-wheels')))
p["4wd"]
# Out:
#           normalized-losses    make fuel-type aspiration num-of-doors  \
# symboling
# 2                       164    audi       gas        std         four
# 0                       192    audi       gas      turbo          two
# 2                        83  subaru       gas        std          two
# 0                       102  subaru       gas        std         four
# 0                       102  subaru       gas      turbo         four
# 0                        85  subaru       gas        std         four
# 0                        85  subaru       gas      turbo         four
# 0                        81  toyota       gas        std         four
# 0                        91  toyota       gas        std         four
#
#           body-style drive-wheels engine-location  wheel-base  length  ...  \
# symboling                                                              ...
# 2              sedan          4wd           front        99.4   176.6  ...
# ...

# %% [markdown]
# There is three vehicles types: Audi, Subaru, Toyota.
# In total 9 vehicles in four-wheel drive.

# %% [markdown]
# #### 13. How many vehicles have rear engine location?

# %%
v = Autoo_df.groupby("engine-location").size()
v
# Out:
# engine-location
# front    202
# rear       3
# dtype: int64

# %% [markdown]
# There seems to be three vehicles with rear engine location

# %% [markdown]
# #### 14. What is the average price of the forward wheel drive (fwd) and rear wheel drive (rwd) category of vehicles?

# %% [markdown]
# Before i can do this task, i have to convert some of my values to int, so that i'm able to compute with number.

# %%
Autoo_df[['normalized-losses']] = Autoo_df[['normalized-losses']].astype('int')
Autoo_df[['bore',
          'horsepower', 
          'stroke',
          'peak-rpm',
          'price'
          ]] = Autoo_df[['bore',
                         'horsepower',
                         'stroke', 
                         'peak-rpm',
                         'price'
                         ]].astype('float')

# %%
grouped = Autoo_df['price'].groupby(Autoo_df['drive-wheels'])
grouped

#groupy = Autoo_df.groupby(['drive-wheels'])
#grouping1 = groupy['price']
#grouping1.mean()

# %%
grouped.mean()
# Out:
# drive-wheels
# 4wd    10928.666667
# fwd     9274.833333
# rwd    19619.947368
# Name: price, dtype: float64

# %% [markdown]
# There mus be something wrong with the number? when i first executed, everything was fine and when i was going to double check before delivering my assigment everything changed? i've tried every possible way to fix it, and i know that my code is right?

# %% [markdown]
# I'm not quite sure what u're asking for and i may be misunderstanding the question, so i'll give u two answers based on my interpretation:
# - The average price in forward wheel drive (fwd) is = 9274.83
#
# - The average price in rear wheel drive (rwd) is = 19619.94
#
# the average rwd and fwd on each vehicles:

# %%
group = Autoo_df.groupby(['make','drive-wheels'])
grouping = group['price']
grouping.mean()
# Out:
# make           drive-wheels
# alfa-romero    rwd             15498.333333
# audi           4wd             16940.000000
#                fwd             17941.000000
# bmw            rwd             26118.750000
# chevrolet      fwd              6007.000000
# dodge          fwd              7875.444444
# honda          fwd              8184.692308
# isuzu          fwd             11048.000000
#                rwd              8916.500000
# jaguar         rwd             34600.000000
# mazda          fwd              8399.545455
#                rwd             14784.000000
# mercedes-benz  rwd             33647.000000
# mercury        rwd             16503.000000
# mitsubishi     fwd              9239.769231
# nissan         fwd              8812.333333
#                rwd             18432.333333
# peugot         rwd             15489.090909
# plymouth       fwd              7163.333333
#                rwd             12764.000000
# porsche        rwd             26979.400000
# ...

# %% [markdown]
# above u will see the average price for rwd and fwd in each vehicle.

# %% [markdown]
# #### 15. What is the average price of rwd-sedan and 4wd-hatchback? Which one is larger?

# %%
group = Autoo_df.groupby(['drive-wheels','body-style'])
grouping = group[['price']]
grouping.mean()
# Out:
#                                  price
# drive-wheels body-style
# 4wd          hatchback    12016.500000
#              sedan        12647.333333
#              wagon         9095.750000
# fwd          convertible  11595.000000
#              hardtop       8249.000000
#              hatchback     8396.387755
#              sedan         9855.175439
#              wagon         9997.333333
# rwd          convertible  23949.600000
#              hardtop      24202.714286
#              hatchback    14072.368421
#              sedan        21711.833333
#              wagon        16994.222222

# %% [markdown]
# - The average price of rwd-sedan is = 21711.83
# - The average price of 4wd-hatchback is = 12016.50

# %%
g = Autoo_df.groupby(['drive-wheels', 'body-style'])
grouped_pct = g[['length', 'width', 'height', 'curb-weight']]
grouped_pct.max()
# Out:
#                           length  width  height  curb-weight
# drive-wheels body-style
# 4wd          hatchback     178.2   67.9    55.7         3053
#              sedan         176.6   66.4    54.3         2824
#              wagon         173.6   65.4    59.1         3110
# fwd          convertible   159.3   64.2    55.6         2254
#              hardtop       162.4   63.8    53.3         2008
#              hatchback     186.6   66.6    56.1         2926
#              sedan         192.7   71.4    56.1         3095
#              wagon         192.7   71.4    59.8         3296
# rwd          convertible   180.3   70.5    53.0         3685
#              hardtop       199.2   72.0    55.4         3715
#              hatchback     183.5   72.3    54.8         3366
#              sedan         208.1   71.7    56.7         4066
#              wagon         198.9   70.3    58.7         3750

# %% [markdown]
# Length:
# * rwd-sedan = 208.1
# * 4wd-hatchback = 178.2
#
# width:
# * rwd-sedan = 71.7
# * 4wd-hatchback = 67.7
#
# height:
# * rwd-sedan = 56.7
# * 4wd-hatchback = 55.7
#
# curb-weight:
# * rwd-sedan = 4066
# * 4wd-hatchback = 3053
#
# Based on our dataframe above, rwd-sedan is clearly larger than 4wd-hatchback.

# %% [markdown]
# ## Problem 4 Web Scraping Problem
# 1. Scrap the table titled: “10 most populous countries” shown below and create a DataFrame named DF_Pop

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://en.wikipedia.org/wiki/World_population'

# %%
d  = requests.get(url).text

# %%
s = BeautifulSoup(d,"html.parser")

# %%
t = s.find_all('table')
t
# Out:
# [<table class="wikitable" style="text-align:center; float:right; clear:right; margin-left:8px; margin-right:0;">
#  <caption>World population milestones in billions<sup class="reference" id="cite_ref-:6_62-0"><a href="#cite_note-:6-62">[62]</a></sup> (Worldometers estimates)
#  </caption>
#  <tbody><tr>
#  <th scope="row">Population
#  </th>
#  <th scope="col">1
#  </th>
#  <th scope="col">2
#  </th>
#  <th scope="col">3
#  </th>
#  <th scope="col">4
#  </th>
#  <th scope="col">5
#  </th>
#  <th scope="col">6
#  </th>
#  <th scope="col">7
#  </th>
#  <th scope="col">8
#  </th>
#  <th scope="col">9
#  </th>
#  <th scope="col">10
#  </th></tr>
#  <tr>
#  <th scope="row">Year
#  </th>
#  <td>1804</td>
#  <td>1930</td>
#  <td>1960</td>
#  <td>1974</td>
#  <td>1987</td>
#  <td>1999</td>
#  <td>2011</td>
#  <td>2022</td>
#  <td><i>2037</i></td>
#  <td><i>2057</i>
#  </td></tr>
#  <tr>
#  <th scope="row">Years elapsed
#  </th>
#  <td>200,000+</td>
#  <td>126</td>
#  <td>30</td>
# ...

# %%
len(t) #Checking out table length
# Out:
# 24

# %%
tables = 3

# %%
DF_Pop = pd.DataFrame(columns=["Country/Dependency", "Population", "Date", "Source(official or from the United Nations)"])

for row in t[tables].tbody.find_all("tr"):
    col = row.find_all("td")
    if (col != []):
        country = col[0].text.strip()
        pop = col[1].text.strip()
        perctentage = col[2]
        date = col[3].text
        source = col[4].text
        DF_Pop = DF_Pop.append({ "Country/Dependency":country, "Population":pop, "Date":date, "Source(official or from the United Nations)":source}, ignore_index=True)
        DF_Pop.index.name = 'Rank'
        DF_Pop.index += 1

DF_Pop
# Out:
# /var/folders/ck/tj22xx3j079_4h8rlfc7mfbm0000gn/T/ipykernel_36156/3390025685.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DF_Pop = DF_Pop.append({ "Country/Dependency":country, "Population":pop, "Date":date, "Source(official or from the United Nations)":source}, ignore_index=True)
# /var/folders/ck/tj22xx3j079_4h8rlfc7mfbm0000gn/T/ipykernel_36156/3390025685.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   DF_Pop = DF_Pop.append({ "Country/Dependency":country, "Population":pop, "Date":date, "Source(official or from the United Nations)":source}, ignore_index=True)
# /var/folders/ck/tj22xx3j079_4h8rlfc7mfbm0000gn/T/ipykernel_36156/3390025685.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
DF_Pop = pd.read_html(url, flavor='bs4')

# %%
len(DF_Pop)
# Out:
# 24

# %% [markdown]
# 2. Create a Bar Chart for the DF_Pop, depicting the country name on X-axis and population on the y-axis.

# %%
import matplotlib.pyplot as plt

# %%
Country = DF_Pop[0]
population = DF_Pop[1]

# %%
plt.bar(Country, population)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 plt.bar(Country, population)
#       3 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2399, in bar(x, height, width, bottom, align, data, **kwargs)
#    2395 @_copy_docstring_and_deprecators(Axes.bar)
#    2396 def bar(
#    2397         x, height, width=0.8, bottom=None, *, align='center',
#    2398         data=None, **kwargs):
# -> 2399     return gca().bar(
#    2400         x, height, width=width, bottom=bottom, align=align,
#    2401         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
# ...

# %%
DF_Pop.plot(x = "Country/Dependency", y = "population", kind="bar", figsize=(7, 6))

# %% [markdown]
#     one of them should work, not quite sure why it doesnt.
